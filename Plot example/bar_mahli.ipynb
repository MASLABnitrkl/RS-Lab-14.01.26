# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
path='D:/Work/RS_Lab/Data/MSL'
os.chdir(path)

df=pd.read_csv('Shivers_sol1793.csv')

# %%
df
# Out:
#        Bins  Frequency
# 0      0-50          0
# 1    50-100         56
# 2   100-150         88
# 3   150-200         83
# 4   200-250        161
# 5   250-300        189
# 6   300-350        133
# 7   350-400         89
# 8   400-450         52
# 9   450-500         22
# 10  500-550          9
# 11  550-600          3
# 12  600-650          1
# 13  650-700          1

# %%
bins=df["Bins"]
freq=df["Frequency"]

# %%
plt.figure(figsize=(10, 10))
plt.bar(bins, freq)
plt.xlabel("Grain size (\u03BCm)")
plt.ylabel("number of grains")
plt.title("Bar diagram of sand grain size distribution")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
